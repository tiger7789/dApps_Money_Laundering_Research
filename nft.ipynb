# %%
import requests

# %%
import requests

project = "4tsxo4vuhotaojtl"
api_key = "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"
base_url = "https://api.dappradar.com/"
headers = {"X-BLOBR-KEY": api_key}

common_query = {
    "range": "15min",
    "sort": "avgPrice",
    "order": "asc",
    "chain": "algorand",
    "page": "1",
    "resultsPerPage": "50",
}
order = "asc"
collection_id = '1'
nft_id = '1'
item_id = '1'

# print out all supported collections chains
url = base_url + project + "/nfts/collections/chains"
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("1",data)

# 2. Get multiple NFT collections data
url = base_url + project + "/nfts/collections"
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("2",data)

# 3. Get single NFT Collection data
url = base_url + project + "/nfts/collection/" + collection_id 
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("3",data)

# 4. Get supported marketplaces chains
url = base_url + project + "/nfts/marketplaces/chains"
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("4",data)

# 5. Get multiple NFT marketplaces data
url = base_url + project + "/nfts/marketplaces"
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("5",data)

# 6. Get supported chains of NFT value estimator
url = base_url + project + "/nfts/value-estimator/chains"
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("6",data)

# 7. Get supported NFT value estimator collections
url = base_url + project + "/nfts/value-estimator/1"
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("7",data)

# 8. Get estimated NFT collection value
url = base_url + project + "/nfts/value-estimator/collection"+ collection_id 
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("8",data)

# 9. Get estimated NFT item value
url = base_url + project + "/nfts/value-estimator/item/" + item_id 
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("9",data)

# 10. Get supported NFT metadata chains
url = base_url + project + "/nfts/metadata/chains"
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("10",data)

chain = "base"
address = "1"
nft_id = "1"
# 11. Get metadata of specific NFT
url = base_url + project + "/nfts/metadata/"+ chain + "/" + address + "/" + nft_id
response = requests.get(url, headers=headers, params=common_query)
data = response.json()
print("11",data)
# Out:
# 1 {'success': True, 'chains': ['algorand', 'arbitrum', 'aurora', 'avalanche', 'base', 'binance-smart-chain', 'bitcoin', 'cardano', 'celo', 'cronos', 'elysium', 'ethereum', 'flow', 'hedera', 'immutablex', 'mooi', 'moonbeam', 'moonriver', 'near', 'polygon', 'ronin', 'solana', 'stacks', 'stargaze', 'starkware', 'tezos', 'theta', 'tron', 'wax', 'xrpl', 'zilliqa', 'zksync-era']}
# ...
