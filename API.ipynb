# %% [markdown]
# ## Dapps 🪙
# Dapps Definition: Decentralized Applications (dApps) are software programs that run on a blockchain network of computers instead of on a single computer.
# Dapp Rader API: over 50 indexed Blockchins -> 12000 dapps.

# %% [markdown]
# ### Get Supported Chains 🔗
# This endpoint returns all supported chains in the dapp ranking.
# ```python
# import requests
#
# project = "4tsxo4vuhotaojtl"
# url = "https://api.dappradar.com/" + project + "/dapps/chains"
#
# headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}
#
# response = requests.get(url, headers=headers)
#
# data = response.json()
#
# ```
# #### 👇The API is supported the following chains👇:
# 'algorand', 'arbitrum', 'astar', 'aurora', 'avalanche', 'base', 'binance-smart-chain', 'cardano', 'celo', 'cronos', 'defikingdoms', 'dep', 'elysium', 'eos', 'ethereum', 'fantom', 'flow', 'harmony', 'hedera', 'hive', 'immutablex', 'iotex', 'klaytn', 'mooi', 'moonbeam', 'moonriver', 'near', 'oasis', 'oasis-sapphire', 'ontology', 'optimism', 'other', 'platon', 'polygon', 'rangers', 'ronin', 'shiden', 'skale', 'solana', 'stacks', 'stargaze', 'steem', 'sxnetwork', 'telos', 'telosevm', 'tezos', 'thundercore', 'tron', 'vechain', 'vulcanforged', 'wax', 'zilliqa', 'zksync-era'
#
# --------------------

# %% [markdown]
# ### Get supported categories👀
# This endpoint returns all supported categories in the dapp rankings.
# ```Python
# import requests
#
# project = "4tsxo4vuhotaojtl"
# url = "https://api.dappradar.com/" + project + "/dapps/categories"
#
# headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}
#
# response = requests.get(url, headers=headers)
#
# data = response.json()
# print(data)
# ```
# #### 👇The API is supported the following categories👇:
# 'games', 'defi', 'collectibles', 'marketplaces', 'high-risk', 'gambling', 'exchanges', 'social', 'other'
#
# --------------------------------

# %% [markdown]
# ### Get multiple Dapps data 📊
# This endpoint returns a list of multiple dapps and pages from a __certain chain__, __specific page__ and expected __results per page__.
# ```Python
# import requests
#
# project = "4tsxo4vuhotaojtl"
# url = "https://api.dappradar.com/" + project + "/dapps"
#
# query = {
#   "chain": "binance-smart-chain",
#   "page": "3",
#   "resultsPerPage": "10"
# }
#
# headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}
#
# response = requests.get(url, headers=headers, params=query)
#
# data = response.json()
# print(data)
# ```
# #### 👇The API does work👇:
# {'success': True, 'results': [{'dappId': 13, 'name': 'OpenSea', 'description': 'OpenSea is the first and largest peer-to-peer marketplace.', 'fullDescription': '<p>OpenSea is the first and largest peer-to-peer marketplace for crypto collectibles, which include gaming items, digital art, and other virtual goods backed by a blockchain.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/13/opensea-dapp-marketplaces-ethereum-logo_a3421ac6e32d529db3c8293f4cfa9bcd.png', 'link': 'https://dappradar.com/dapp/opensea', 'website': 'https://opensea.io', 'chains': ['arbitrum', 'avalanche', 'base', 'binance-smart-chain', 'ethereum', 'klaytn', 'optimism', 'polygon', 'solana'], 'categories': ['marketplaces'], 'socialLinks': [{'title': 'discord', 'url': 'https://discord.gg/zAHt7Tb', 'type': 'discord'}, {'title': 'facebook', 'url': 'https://facebook.com/projectopensea', 'type': 'facebook'}, {'title': 'medium', 'url': 'https://medium.com/@opensea', 'type': 'medium'}, {'title': 'reddit', 'url': 'https://reddit.com/r/opensea', 'type': 'reddit'}, {'title': 'twitter', 'url': 'https://twitter.com/projectopensea', 'type': 'twitter'}], 'tags': []}, {'dappId': 257, 'name': '0x Protocol', 'description': '0x is an open protocol that enables the peer-to-peer exchange of assets on the Ethereum blockchain.', 'fullDescription': '<p>0x is an open protocol that enables the peer-to-peer exchange of assets on the Ethereum blockchain.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/257/0xprotocol-dapp-other-eth-logo_7e869e1e5fbe2b41499661ea503195bd.png', 'link': 'https://dappradar.com/dapp/0x-protocol', 'website': 'https://www.0x.org/', 'chains': ['arbitrum', 'avalanche', 'binance-smart-chain', 'celo', 'ethereum', 'fantom', 'optimism', 'polygon'], 'categories': ['exchanges'], 'socialLinks': [{'title': 'twitter', 'url': 'https://twitter.com/0xProject', 'type': 'twitter'}], 'tags': [{'id': '10', 'name': 'Layer 2', 'slug': 'layer-2'}, {'id': '11', 'name': 'Content Creation', 'slug': 'content-creation'}, {'id': '12', 'name': 'Art', 'slug': 'art'}, {'id': '13', 'name': 'Pools', 'slug': 'pools'}, {'id': '14', 'name': 'Gambling', 'slug': 'gambling'}, {'id': '15', 'name': 'Knowledge', 'slug': 'knowledge'}, {'id': '16', 'name': 'Farming', 'slug': 'farming'}, {'id': '18', 'name': 'Discussions', 'slug': 'discussions'}, {'id': '19', 'name': 'Photos', 'slug': 'photos'}, {'id': '1', 'name': 'NFT', 'slug': 'nft'}, {'id': '20', 'name': 'Videos', 'slug': 'videos'}, {'id': '21', 'name': 'Move to Earn', 'slug': 'move-to-earn'}, {'id': '22', 'name': 'Metaverse', 'slug': 'metaverse'}, {'id': '23', 'name': 'Sports', 'slug': 'sports'}, {'id': '24', 'name': 'Social', 'slug': 'social'}, {'id': '2', 'name': 'Exchanges', 'slug': 'exchanges'}, {'id': '3', 'name': 'Staking', 'slug': 'staking'}, {'id': '4', 'name': 'Yield', 'slug': 'yield'}, {'id': '5', 'name': 'DeFi', 'slug': 'defi'}, {'id': '6', 'name': 'Games', 'slug': 'games'}, {'id': '7', 'name': 'Play to Earn', 'slug': 'play-to-earn'}, {'id': '8', 'name': 'Marketplaces', 'slug': 'marketplaces'}, {'id': '9', 'name': 'Governance', 'slug': 'governance'}]}, {'dappId': 328, 'name': 'AirSwap', 'description': 'AirSwap powers peer-to-peer trading.', 'fullDescription': '<p>AirSwap powers peer-to-peer trading. Using a decentralized request-for-quote (RFQ) protocol, AirSwap traders are protected from front-running and price slippage. AirSwap uses an open development process called AIP that you can participate in as a token holder.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/328/airswap-dapp-exchanges-eth-logo_72b6f772a82b13d0daed44a91b8c2624.png', 'link': 'https://dappradar.com/dapp/airswap', 'website': 'https://www.airswap.io/', 'chains': ['arbitrum', 'avalanche', 'binance-smart-chain', 'ethereum', 'polygon'], 'categories': ['exchanges'], 'socialLinks': [{'title': 'discord', 'url': 'https://chat.airswap.io/', 'type': 'discord'}, {'title': 'facebook', 'url': 'https://www.facebook.com/airswapio/', 'type': 'facebook'}, {'title': 'github', 'url': 'https://github.com/airswap', 'type': 'github'}, {'title': 'instagram', 'url': 'https://www.instagram.com/airswap', 'type': 'instagram'}, {'title': 'medium', 'url': 'https://medium.com/@airswap', 'type': 'medium'}, {'title': 'reddit', 'url': 'https://www.reddit.com/r/AirSwap/', 'type': 'reddit'}, {'title': 'telegram', 'url': 'https://t.me/airswap', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/airswap', 'type': 'twitter'}], 'tags': []}, {'dappId': 764, 'name': 'Summer.fi', 'description': 'DeFi made simple and secure: take advantage of powerful automation strategies and user-friendly UX across multiple protocols and layers.', 'fullDescription': '<p>Summer.fi is a platform for decentralized finance. It can be used to borrow stablecoins against users’ favorite cryptocurrencies, increase exposure against them using Multiply, or Earn a competitive yield. This can be done across multiple protocols and Layers — all in one place. Summer.fi’s mission is to provide the most trusted entry point to deploy capital into DeFi. The team is made of passionate thinkers and builders driven to create a better user experience for all while being able to maximize returns.&nbsp;</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/764/oasisapp-dapp-defi-764-logo_1e5311680e6fdd95205b13c77d6e2ff0.png', 'link': 'https://dappradar.com/dapp/summer-fi', 'website': 'https://summer.fi/', 'chains': ['aurora', 'avalanche', 'binance-smart-chain', 'cronos', 'ethereum', 'fantom', 'moonbeam', 'moonriver', 'optimism'], 'categories': ['defi'], 'socialLinks': [{'title': 'blog', 'url': 'https://blog.summer.fi/', 'type': 'blog'}, {'title': 'discord', 'url': 'https://discord.gg/summerfi', 'type': 'discord'}, {'title': 'twitter', 'url': 'https://twitter.com/summerfinance_', 'type': 'twitter'}], 'tags': []}, {'dappId': 1254, 'name': 'RigoBlock', 'description': 'Swap, earn and interact with DeFi through Smart Pools.', 'fullDescription': '<p>RigoBlock is a protocol for asset management, streamlining interaction with DEXes and DeFi applications. Users create Smart Pools, which are capable of holding tokens on behalf of multiple wallets, and allow their operators to swap and earn on DeFi with easier interaction, fewer transactions than regular Dapps, and increased security.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/1254/rigoblock-dapp-defi-1254-logo_80ec75102679c3782fc8649d4a8b246d.png', 'link': 'https://dappradar.com/dapp/rigoblock', 'website': 'https://app.rigoblock.com', 'chains': ['arbitrum', 'binance-smart-chain', 'ethereum', 'optimism', 'polygon'], 'categories': ['exchanges', 'defi'], 'socialLinks': [{'title': 'cmc', 'url': 'https://coinmarketcap.com/currencies/rigoblock/', 'type': 'cmc'}, {'title': 'coingecko', 'url': 'https://www.coingecko.com/en/coins/rigoblock', 'type': 'coingecko'}, {'title': 'discord', 'url': 'https://discord.gg/FXd8EU8', 'type': 'discord'}, {'title': 'github', 'url': 'https://github.com/RigoBlock', 'type': 'github'}, {'title': 'twitter', 'url': 'https://t.me/rigoblockprotocol', 'type': 'twitter'}], 'tags': [{'id': '10', 'name': 'Layer 2', 'slug': 'layer-2'}, {'id': '11', 'name': 'Content Creation', 'slug': 'content-creation'}, {'id': '12', 'name': 'Art', 'slug': 'art'}, {'id': '13', 'name': 'Pools', 'slug': 'pools'}, {'id': '14', 'name': 'Gambling', 'slug': 'gambling'}, {'id': '15', 'name': 'Knowledge', 'slug': 'knowledge'}, {'id': '16', 'name': 'Farming', 'slug': 'farming'}, {'id': '18', 'name': 'Discussions', 'slug': 'discussions'}, {'id': '19', 'name': 'Photos', 'slug': 'photos'}, {'id': '1', 'name': 'NFT', 'slug': 'nft'}, {'id': '20', 'name': 'Videos', 'slug': 'videos'}, {'id': '21', 'name': 'Move to Earn', 'slug': 'move-to-earn'}, {'id': '22', 'name': 'Metaverse', 'slug': 'metaverse'}, {'id': '23', 'name': 'Sports', 'slug': 'sports'}, {'id': '24', 'name': 'Social', 'slug': 'social'}, {'id': '2', 'name': 'Exchanges', 'slug': 'exchanges'}, {'id': '3', 'name': 'Staking', 'slug': 'staking'}, {'id': '4', 'name': 'Yield', 'slug': 'yield'}, {'id': '5', 'name': 'DeFi', 'slug': 'defi'}, {'id': '6', 'name': 'Games', 'slug': 'games'}, {'id': '7', 'name': 'Play to Earn', 'slug': 'play-to-earn'}, {'id': '8', 'name': 'Marketplaces', 'slug': 'marketplaces'}, {'id': '9', 'name': 'Governance', 'slug': 'governance'}]}, {'dappId': 1528, 'name': '1inch Network', 'description': 'A distributed DeFi aggregator for various protocols on multiple chains.', 'fullDescription': '<p>The 1inch Network seamlessly unites multiple decentralized protocols, empowering users to perform efficient, user-friendly and secure operations in the Web3 space.</p>\n<p>The 1inch Network provides access to hundreds of liquidity sources across multiple blockchains. Its main components are the 1inch Aggregation Protocol, the 1inch Liquidity Protocol, the 1inch Limit Order Protocol and the 1inch Wallet – a fast and secure mobile application for storing, receiving, sending and swapping crypto assets.</p>\n<p>The 1inch Swap Engine, built on top of 1inch’s Aggregation Protocol and Limit Order Protocol, is a decentralized trading and matching system that connects DEX users with practically limitless liquidity. The 1inch Swap Engine executes trade orders using the Dutch auction model, providing more efficiency, flexibility and tunability than regular swaps or limit orders.</p>\n<p>Powered by the 1inch Swap Engine, Fusion mode enables users to swap tokens without paying any network fees and at the most favorable rates. In addition, Fusion mode offers users extra MEV protection. All swaps in Fusion mode are executed by resolvers – professional traders, who use the most sophisticated and efficient ways of protecting users’ swaps from MEV.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/1528/1inchexchange-dapp-exchanges-ethereum-logo_855963bbf18d4c089e92160b47b43342.png', 'link': 'https://dappradar.com/dapp/1inch-network', 'website': 'https://app.1inch.io', 'chains': ['arbitrum', 'aurora', 'avalanche', 'binance-smart-chain', 'ethereum', 'fantom', 'klaytn', 'optimism', 'polygon', 'zksync-era'], 'categories': ['exchanges', 'defi'], 'socialLinks': [{'title': 'discord', 'url': 'https://discord.com/invite/1inch', 'type': 'discord'}, {'title': 'facebook', 'url': 'https://www.facebook.com/1inchNetwork', 'type': 'facebook'}, {'title': 'github', 'url': 'https://github.com/1inch', 'type': 'github'}, {'title': 'medium', 'url': 'https://blog.1inch.io', 'type': 'medium'}, {'title': 'other', 'url': 'https://t.me/OneInchNetwork', 'type': 'other'}, {'title': 'reddit', 'url': 'https://www.reddit.com/r/1inch/', 'type': 'reddit'}, {'title': 'twitter', 'url': 'https://twitter.com/1inch', 'type': 'twitter'}, {'title': 'youtube', 'url': 'https://www.youtube.com/c/1inch-network', 'type': 'youtube'}], 'tags': [{'id': '10', 'name': 'Layer 2', 'slug': 'layer-2'}, {'id': '11', 'name': 'Content Creation', 'slug': 'content-creation'}, {'id': '12', 'name': 'Art', 'slug': 'art'}, {'id': '13', 'name': 'Pools', 'slug': 'pools'}, {'id': '14', 'name': 'Gambling', 'slug': 'gambling'}, {'id': '15', 'name': 'Knowledge', 'slug': 'knowledge'}, {'id': '16', 'name': 'Farming', 'slug': 'farming'}, {'id': '18', 'name': 'Discussions', 'slug': 'discussions'}, {'id': '19', 'name': 'Photos', 'slug': 'photos'}, {'id': '1', 'name': 'NFT', 'slug': 'nft'}, {'id': '20', 'name': 'Videos', 'slug': 'videos'}, {'id': '21', 'name': 'Move to Earn', 'slug': 'move-to-earn'}, {'id': '22', 'name': 'Metaverse', 'slug': 'metaverse'}, {'id': '23', 'name': 'Sports', 'slug': 'sports'}, {'id': '24', 'name': 'Social', 'slug': 'social'}, {'id': '2', 'name': 'Exchanges', 'slug': 'exchanges'}, {'id': '3', 'name': 'Staking', 'slug': 'staking'}, {'id': '4', 'name': 'Yield', 'slug': 'yield'}, {'id': '5', 'name': 'DeFi', 'slug': 'defi'}, {'id': '6', 'name': 'Games', 'slug': 'games'}, {'id': '7', 'name': 'Play to Earn', 'slug': 'play-to-earn'}, {'id': '8', 'name': 'Marketplaces', 'slug': 'marketplaces'}, {'id': '9', 'name': 'Governance', 'slug': 'governance'}]}, {'dappId': 1592, 'name': 'Tornado Cash', 'description': 'Tornado.cash helps you to reclaim your privacy.', 'fullDescription': '<p>Tornado.cash helps you to reclaim your privacy. You can use it to send Ether to any address in a way that obscures your sending address. It does this using zero-knowledge proofs. You can use this app to deposit some ETH into a non-custodial smart contract, and then easily generate a proof that you had perfomed said deposit without revealing your original address. The app will then send this proof to an operator, which will submit it to the smart contract, which will in turn send the ETH to the desired recipient and reimburse the operator a small fee.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/1592/tornadocash-dapp-other-eth-logo_61674466a4561d1162023456421ea0d3.png', 'link': 'https://dappradar.com/dapp/tornado-cash', 'website': 'https://tornado.cash/', 'chains': ['avalanche', 'binance-smart-chain', 'ethereum', 'polygon'], 'categories': ['other'], 'socialLinks': [{'title': 'twitter', 'url': 'https://twitter.com/TornadoCash', 'type': 'twitter'}], 'tags': []}, {'dappId': 1627, 'name': 'PoolTogether', 'description': "Win by saving.\nPoolTogether is a crypto-powered savings protocol based on Premium Bonds. Save money and have a chance\nThe world's savings protocol, run by you.", 'fullDescription': '<p><strong>PoolTogether is a decentralized and open source blockchain protocol for prize-linked savings.</strong></p>\n<p>Replicating "prize-linked savings accounts" all depositors are offered a chance to win prizes without needing to risk their deposited funds. This is possible because prizes are made up of the interest that accrues on all deposited funds.</p>\n<p>Users deposit into the network</p>\n<p>&nbsp;Yield accrues on all deposits</p>\n<p>&nbsp;The yield is randomly awarded as prizes to the users.</p>\n<p><strong>The PoolTogether protocol has been live for over 3 years and distributed over $5 million in prizes to depositors. The luckiest winner so far deposited $74 and won over $40,000. </strong>PoolTogether is one of the first and most widely used decentralized finance applications. It helps people save money by giving them the chance to win prizes.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/1627/pooltogether-dapp-defi-ethereum-logo_c7c28edc82fc4ace1c008c97e9230bee.png', 'link': 'https://dappradar.com/dapp/pooltogether', 'website': 'https://pooltogether.com', 'chains': ['avalanche', 'binance-smart-chain', 'celo', 'ethereum', 'optimism', 'polygon'], 'categories': ['defi'], 'socialLinks': [{'title': 'medium', 'url': 'https://medium.com/pooltogether', 'type': 'medium'}, {'title': 'twitter', 'url': 'https://twitter.com/PoolTogether_', 'type': 'twitter'}], 'tags': [{'id': '10', 'name': 'Layer 2', 'slug': 'layer-2'}, {'id': '11', 'name': 'Content Creation', 'slug': 'content-creation'}, {'id': '12', 'name': 'Art', 'slug': 'art'}, {'id': '13', 'name': 'Pools', 'slug': 'pools'}, {'id': '14', 'name': 'Gambling', 'slug': 'gambling'}, {'id': '15', 'name': 'Knowledge', 'slug': 'knowledge'}, {'id': '16', 'name': 'Farming', 'slug': 'farming'}, {'id': '18', 'name': 'Discussions', 'slug': 'discussions'}, {'id': '19', 'name': 'Photos', 'slug': 'photos'}, {'id': '1', 'name': 'NFT', 'slug': 'nft'}, {'id': '20', 'name': 'Videos', 'slug': 'videos'}, {'id': '21', 'name': 'Move to Earn', 'slug': 'move-to-earn'}, {'id': '22', 'name': 'Metaverse', 'slug': 'metaverse'}, {'id': '23', 'name': 'Sports', 'slug': 'sports'}, {'id': '24', 'name': 'Social', 'slug': 'social'}, {'id': '2', 'name': 'Exchanges', 'slug': 'exchanges'}, {'id': '3', 'name': 'Staking', 'slug': 'staking'}, {'id': '4', 'name': 'Yield', 'slug': 'yield'}, {'id': '5', 'name': 'DeFi', 'slug': 'defi'}, {'id': '6', 'name': 'Games', 'slug': 'games'}, {'id': '7', 'name': 'Play to Earn', 'slug': 'play-to-earn'}, {'id': '8', 'name': 'Marketplaces', 'slug': 'marketplaces'}, {'id': '9', 'name': 'Governance', 'slug': 'governance'}]}, {'dappId': 1699, 'name': 'ParaSwap', 'description': 'ParaSwap is the fastest DEX aggregator for traders', 'fullDescription': '<p>ParaSwap is the fastest DEX aggregator for traders and dApps. The software is made for dApps and traders who need swaps and payment capabilities while getting the best market rates and cheaper gas fees. Any dApp or trading software can plug into ParaSwap using our API or open source SDK.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/1699/paraswapio-dapp-exchanges-ethereum-logo_dd922d8bafe2f8433bfff4b6721dc066.png', 'link': 'https://dappradar.com/dapp/paraswap', 'website': 'https://paraswap.io', 'chains': ['arbitrum', 'avalanche', 'binance-smart-chain', 'ethereum', 'fantom', 'optimism', 'polygon'], 'categories': ['exchanges'], 'socialLinks': [{'title': 'twitter', 'url': 'https://twitter.com/paraswap', 'type': 'twitter'}], 'tags': []}, {'dappId': 3673, 'name': 'Actifit', 'description': 'Actifit incentivizes healthy living by enabling you to track your everyday activity', 'fullDescription': '<p>Actifit incentivizes healthy living by enabling you to track your everyday activity, and get rewarded with Actifit (AFIT) tokens, but also STEEM rewards via upvotes on your Steem posts.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/3673/actifit-dapp-other-hive-logo_30901f216ee766cd0766936af3a198ec.png', 'link': 'https://dappradar.com/dapp/actifit', 'website': 'https://actifit.io', 'chains': ['binance-smart-chain', 'hive', 'steem'], 'categories': ['other'], 'socialLinks': [], 'tags': []}], 'page': 1, 'pageCount': 506, 'resultCount': 5059, 'resultsPerPage': 10}
#
#
# --------------------------------

# %% [markdown]
# ### Get signle Dapps data 📊
# This endpoint provides users, transactions, volume, balance for a specific dapp. Input is required as the dappId, timeframe (24 hours, 7d or 30d) and chains for data retrieval. The dappId can be sourced from the paginated list or the dapp's about page.
# ```Python
# import requests
#
# dapp_id = "YOUR_dappId_PARAMETER" #Need to provide adappId in order to run the following code.
# project = "4tsxo4vuhotaojtl"
# url = "https://api.dappradar.com/" + project + "/dapps/" + "13" #dapp_id
#
# query = {
#   "chain": "binance-smart-chain",
#   "range": "24h"
# }
#
# headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}
#
# response = requests.get(url, headers=headers, params=query)
#
# data = response.json()
# print(data)
# ```
# #### 👇The API does work👇:
# * Test with DappId #13.
#
#
# {'success': True, 'range': '24h', 'chain': 'binance-smart-chain', 'results': {'dappId': 13, 'name': 'OpenSea', 'description': 'OpenSea is the first and largest peer-to-peer marketplace.', 'fullDescription': '<p>OpenSea is the first and largest peer-to-peer marketplace for crypto collectibles, which include gaming items, digital art, and other virtual goods backed by a blockchain.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/13/opensea-dapp-marketplaces-ethereum-logo-166x166_f8aad6af2930b1edbeaee6457a505d1b.png', 'link': 'https://dappradar.com/dapp/opensea', 'website': 'https://opensea.io', 'tokens': [], 'categories': ['marketplaces'], 'socialLinks': [{'title': 'twitter', 'url': 'https://twitter.com/projectopensea', 'type': 'twitter'}, {'title': 'medium', 'url': 'https://medium.com/@opensea', 'type': 'medium'}, {'title': 'discord', 'url': 'https://discord.gg/zAHt7Tb', 'type': 'discord'}, {'title': 'reddit', 'url': 'https://reddit.com/r/opensea', 'type': 'reddit'}, {'title': 'facebook', 'url': 'https://facebook.com/projectopensea', 'type': 'facebook'}], 'tags': [], 'metrics': {'transactions': 70, 'transactionsPercentageChange': -4.11, 'uaw': 52, 'uawPercentageChange': -8.77, 'volume': 1177.46, 'volumePercentageChange': 1708.85, 'balance': 152.52, 'balancePercentageChange': -0.73}, 'chains': ['binance-smart-chain'], 'firstTransactionDate': '2022-06-19'}}
#
#
# --------------------------------

# %% [markdown]
# ### Get multiple Dapps data 📊
# This endpoint returns a list of multiple dapps and pages from a certain chain, specific page and expected results per page.
#
# ```Python
# import requests
#
# project = "4tsxo4vuhotaojtl"
# url = "https://api.dappradar.com/" + project + "/dapps"
#
# query = {
#   "chain": "binance-smart-chain",
#   "page": "1",
#   "resultsPerPage": "10"
# }
#
# headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}
#
# response = requests.get(url, headers=headers, params=query)
#
# data = response.json()
# print(data)
#
#
# ```
# ### Here is the output
#
# {'success': True, 'results': [{'dappId': 4601, 'name': 'Beefy Finance', 'description': 'The Multichain Yield Optimizer that autocompounds your crypto on BSC, Polygon, Fantom, HECO and Avalanche', 'fullDescription': "<p>Beefy Finance is a Decentralized, Multi-Chain Yield Optimizer platform that allows its users to earn compound interest on their crypto holdings.</p>\n<p>Through a set of investment strategies secured and enforced by smart contracts, Beefy Finance automatically maximizes the user rewards from various liquidity pools (LPs),\u200c \u200cautomated market making (AMM) projects,\u200c \u200cand\u200c \u200cother yield\u200c farming \u200copportunities in the DeFi ecosystem.</p>\n<p>The main product offered by Beefy Finance are the 'Vaults' in which you stake your crypto tokens. The investment strategy tied to the specific vault will automatically increase your deposited token amount by compounding arbitrary yield farm reward tokens back into your initially deposited asset. Despite the name 'Vault' suggests, your funds are never locked in any vault on Beefy Finance: you can always withdraw at any moment in time.</p>\n<p>DeFi applications are unique in the sense that they are permissionless and trustless, meaning that anyone with a supported wallet can interact with them without the need for a trusted middleman. While you have funds staked in a vault, you remain 100% in control of your crypto.</p>", 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4601/beefyfinance-dapp-defi-bsc-logo_d055d0802b7341e2575f768efc573ad8.png', 'link': 'https://dappradar.com/dapp/beefy-finance', 'website': 'https://beefy.finance/', 'chains': ['arbitrum', 'aurora', 'avalanche', 'base', 'binance-smart-chain', 'celo', 'cronos', 'fantom', 'moonbeam', 'moonriver', 'optimism', 'polygon'], 'categories': ['defi'], 'socialLinks': [{'title': 'discord', 'url': 'https://discord.com/invite/yq8wfHd', 'type': 'discord'}, {'title': 'github', 'url': 'https://github.com/beefyfinance', 'type': 'github'}, {'title': 'telegram', 'url': 'https://t.me/beefyfinance', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/beefyfinance', 'type': 'twitter'}, {'title': 'youtube', 'url': 'https://www.youtube.com/c/BeefyFinance', 'type': 'youtube'}], 'tags': []}, {'dappId': 4602, 'name': 'BFis.Finance', 'description': 'BFI is a liquidity mining project based on binance smart chain, committed to become YFI on BSC.', 'fullDescription': '<p>BFI is a liquidity mining project based on binance smart chain, committed to become YFI on BSC. On the basis of forming a strong consensus community, it develops new decentralized products through community iteration.</p>\n<p><strong>Highlights of the project</strong></p>\n<ul>\n  <li>The total supply of BFI is 30000, and community autonomy.</li>\n  <li>Zero pre exmining, no private placement and no reservation. The token is obtained through mining, which gives back to the small partners growing up with BSC .</li>\n  <li>Based on BSC, there is no congestion and high gas in Ethereum.</li>\n</ul>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4602/bfisfinance-dapp-defi-bsc-logo_cef1c1d4a712a50fd9229b53fd4dfc11.png', 'link': 'https://dappradar.com/dapp/bfis-finance', 'website': 'https://bfis.finance/', 'chains': ['binance-smart-chain'], 'categories': ['defi'], 'socialLinks': [{'title': 'medium', 'url': 'https://medium.com/@bfi.finance', 'type': 'medium'}, {'title': 'telegram', 'url': 'https://t.me/bfi_finance_EN', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/BFIS_Finance', 'type': 'twitter'}], 'tags': []}, {'dappId': 4603, 'name': 'SwapTuna', 'description': 'Yield Farming with Liquidity & Decentralized Exchange with Automatic Market Making on Binance Smart Chain.', 'fullDescription': '<p>TunaSwap is a new project built on Binance Smart Chain, innovated by SushiSwap. It has two parts, the Tuna Farm, which is yield farming by liquidity, and the Swap, which is a decentralized exchange. Like other types of SushiSwap products, TunaSwap adopts the model of automatic market maker(AMM).</p>\n<p>Like SushiSwap, TunaSwap distributes 10% of its funding each time to the founding team for development, future iterations, audits, etc.</p>\n<p>In TunaSwap, while users are rewarded with fees, they can as well use their LP tokens to earn TUNA token in Tuna Farm. Later even when they removed their liquidity, they still hold the TUNA token, which, can be staked to earn more TUNA(from the Tuna Warehouse, which reserves 1/6 fee for all TUNA holders). The Tuna token serves as a ‘certificate’ of their contribution to the platform.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4603/swaptuna-dapp-defi-bsc-logo_92e158ea08bb092e56af979f30aafe74.png', 'link': 'https://dappradar.com/dapp/swaptuna', 'website': 'https://swaptuna.com/', 'chains': ['binance-smart-chain'], 'categories': ['defi'], 'socialLinks': [{'title': 'medium', 'url': 'https://medium.com/@swaptuna', 'type': 'medium'}, {'title': 'telegram', 'url': 'https://t.me/SwapTuna', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/SwapTuna', 'type': 'twitter'}], 'tags': []}, {'dappId': 4604, 'name': 'StakeCow', 'description': 'First yield farm on Binance Smart Chain.', 'fullDescription': '<p><strong>The Protocol</strong></p>\n<p>When cow comes, everyone wants to get milked. The Milk Protocol is designed to yield MILK for those who want to get milked. Stake tokens on Cow, got MILK for free.</p>\n<p><strong>Milk Token</strong></p>\n<ul>\n  <li>Total Supply: 13292 MILK</li>\n  <li>First Distribution Pool：WBNB</li>\n</ul>\n<p><strong>Distribution</strong></p>\n<p>Rather than allocating a portion of the supply to the founding team, MILK is being distributed with no premine, no founder shares, no VC interests — simply equal-opportunity staking distribution to attract a broad and vision-aligned community to steward the future of the protocol and token.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4604/stakecow-dapp-defi-bsc-logo_7f59831929a114f3769cccfd2d327c34.png', 'link': 'https://dappradar.com/dapp/stakecow', 'website': 'https://stakecow.com/', 'chains': ['binance-smart-chain'], 'categories': ['defi'], 'socialLinks': [{'title': 'github', 'url': 'https://github.com/milk-protocol', 'type': 'github'}, {'title': 'telegram', 'url': 'https://t.me/stakecow_en', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/StakeCow', 'type': 'twitter'}], 'tags': []}, {'dappId': 4632, 'name': 'Cross Finance', 'description': "An inter-chain swapping & multi-chain liquidity pool platform, Cross Finance assembles 'DeFi debris' into one.", 'fullDescription': "<p>An inter-chain swapping &amp; multi-chain liquidity pool platform, Cross Finance assembles 'DeFi debris' into one. One of the problems of DeFi is that it is fragmented by high-traction DeFi dapps standing separately in different blockchains. Cross Finance's solution is to connect all chains &amp; allow users to swap &amp; yield-farm on native &amp; synthetic assets. With Cross Finance, you trade &amp; harvest without any borders</p>\n<p>&nbsp;</p>", 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4632/crossfinance-dapp-defi-bsc-logo_b9ea17c3b4698c35a7c559c0ebfea069.png', 'link': 'https://dappradar.com/dapp/cross-finance', 'website': 'https://crossfin.io/', 'chains': ['binance-smart-chain'], 'categories': ['defi'], 'socialLinks': [{'title': 'github', 'url': 'https://github.com/crossfin', 'type': 'github'}, {'title': 'medium', 'url': 'https://medium.com/cross-finance-defi', 'type': 'medium'}, {'title': 'twitter', 'url': 'https://twitter.com/Crossfinio', 'type': 'twitter'}], 'tags': []}, {'dappId': 4643, 'name': 'BakerySwap', 'description': 'BakerySwap is the first AMM+NFT platform on Binance Smart Chain.', 'fullDescription': "<ul>\n  <li>BakerySwap is a decentralized <strong>automated market-making (AMM)</strong> protocol on Binance Smart Chain(BSC) and the 1st NFT trading platform on BSC - 'Bakery NFT Supermarket'. &nbsp;BakerySwap is the next iteration of Uniswap. It aims to be a faster, cheaper, and tastier version of Uniswap.&nbsp;</li>\n  <li>BAKE token is the native BEP-20 governance token of the platform. Users can earn BAKE tokens by providing liquidity on BakerySwap. BAKE holders can use their tokens for <strong>governance voting</strong> as well as for receiving <strong>transaction fee dividends</strong>.</li>\n  <li>BAKE can be used to compose a random combo meal, which is a unique NFT(None-fungible token). Your unique NFT combo is not only a collectible item, but also a BAKE farming tool. Each NFT combo has a staking power and can be staked to earn BAKE.</li>\n  <li>BAKE rewards are offered to several liquidity pools in different proportions, initially including: <strong>BUSD, ETH, BTC, DOT, LINK, and BAKE versus BNB</strong>.&nbsp;</li>\n  <li>BakerySwap features a 0.30% fee to all trades, of which <strong>0.25%</strong> will go to <strong>Liquidity Providers (LPs)</strong>, and the remaining <strong>0.05%</strong> will be converted to BAKE tokens and given to BAKE holders as rewards.</li>\n  <li>The team is an anonymous group of developers who believe in the future of decentralized autonomous organizations (DAO). It does not believe in pre-sale or tokens pre-reserved for the team. The team will receive a relatively low share of rewards during the entire BAKE farming period, which is 1 BAKE for every 100 BAKE farmed.</li>\n</ul>", 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4643/bakeryswap-dapp-defi-bsc-logo_d8c635f619c0626f259711f9b3cadf53.png', 'link': 'https://dappradar.com/dapp/bakeryswap', 'website': 'https://www.bakeryswap.org', 'chains': ['binance-smart-chain'], 'categories': ['defi'], 'socialLinks': [{'title': 'github', 'url': 'https://github.com/BakeryProject', 'type': 'github'}, {'title': 'medium', 'url': 'https://medium.com/@BakerySwap', 'type': 'medium'}, {'title': 'telegram', 'url': 'https://t.me/bakeryswap', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/bakery_swap', 'type': 'twitter'}], 'tags': []}, {'dappId': 4653, 'name': 'BambooSwap', 'description': 'The first Defi+Game decentralization AMM Dex on Binance smart chain .', 'fullDescription': '<p>The first Defi+Game decentralization AMM Dex on Binance smart chain .</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4653/bambooswap-dapp-defi-bsc-logo_463d4687c82586eee2cd2d3fea2fdc97.png', 'link': 'https://dappradar.com/dapp/bambooswap', 'website': 'https://bambooswap.org', 'chains': ['binance-smart-chain'], 'categories': ['exchanges'], 'socialLinks': [{'title': 'medium', 'url': 'https://medium.com/@BambooswapGod', 'type': 'medium'}, {'title': 'telegram', 'url': 'https://t.me/BambooSwap', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/Bamboo_Swap', 'type': 'twitter'}], 'tags': []}, {'dappId': 4667, 'name': 'Clash of Coins', 'description': 'The first Blockchain MMORTS that you can really play', 'fullDescription': "<p><strong>Clash of Coins</strong> is the first blockchain-based MMORTS with support for more than 100,000 players.</p>\n<p>For years now the world of cryptocurrency has been debating which coin is the best is and which is the future of cryptocurrency.</p>\n<p>We'd like to offer our perspective on this debate.</p>\n<p>That's why we've created the largest browser-based map in history, and we're going to use it to wage a decisive battle for worldwide crypto-domination.</p>\n<p><strong>- Unite</strong></p>\n<p>Team up with like-minded players to fight beneath the banners of real coins</p>\n<p><strong>- Conquer</strong></p>\n<p>Take part in massive battles and conquer entire countries</p>\n<p>- <strong>Get Crypto</strong></p>\n<p>Every 24 hours the best clans are rewarded with real cryptocurrency</p>", 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4667/clashofcoins-dapp-games-ethereum-logo_d32182c5a58d47d6268d12116ba6ebe0.png', 'link': 'https://dappradar.com/dapp/clash-of-coins', 'website': 'https://clashofcoins.com/', 'chains': ['binance-smart-chain', 'ethereum'], 'categories': ['games'], 'socialLinks': [{'title': 'telegram', 'url': 'https://t.me/clashofcoins', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/clashofcoinscom', 'type': 'twitter'}], 'tags': [{'id': '10', 'name': 'Layer 2', 'slug': 'layer-2'}, {'id': '11', 'name': 'Content Creation', 'slug': 'content-creation'}, {'id': '12', 'name': 'Art', 'slug': 'art'}, {'id': '13', 'name': 'Pools', 'slug': 'pools'}, {'id': '14', 'name': 'Gambling', 'slug': 'gambling'}, {'id': '15', 'name': 'Knowledge', 'slug': 'knowledge'}, {'id': '16', 'name': 'Farming', 'slug': 'farming'}, {'id': '18', 'name': 'Discussions', 'slug': 'discussions'}, {'id': '19', 'name': 'Photos', 'slug': 'photos'}, {'id': '1', 'name': 'NFT', 'slug': 'nft'}, {'id': '20', 'name': 'Videos', 'slug': 'videos'}, {'id': '21', 'name': 'Move to Earn', 'slug': 'move-to-earn'}, {'id': '22', 'name': 'Metaverse', 'slug': 'metaverse'}, {'id': '23', 'name': 'Sports', 'slug': 'sports'}, {'id': '24', 'name': 'Social', 'slug': 'social'}, {'id': '2', 'name': 'Exchanges', 'slug': 'exchanges'}, {'id': '3', 'name': 'Staking', 'slug': 'staking'}, {'id': '4', 'name': 'Yield', 'slug': 'yield'}, {'id': '5', 'name': 'DeFi', 'slug': 'defi'}, {'id': '6', 'name': 'Games', 'slug': 'games'}, {'id': '7', 'name': 'Play to Earn', 'slug': 'play-to-earn'}, {'id': '8', 'name': 'Marketplaces', 'slug': 'marketplaces'}, {'id': '9', 'name': 'Governance', 'slug': 'governance'}]}, {'dappId': 4686, 'name': 'SmartSwap', 'description': 'Binance Smart Chain to Ethereum 1:1 swap which creates cross-chain shared pooling between PancakeSwap (BEP20) and UniSwap (ERC20)', 'fullDescription': '<p>Binance Smart Chain to Ethereum ONE CLICK and 1:1 swap which creates cross-chain shared pooling between PancakeSwap (BEP20) and UniSwap (ERC20). By adding UniSwap liquidity to BSC, JNTR, JNTR/b, and JNTR/e investors are presented with new DeFi options bridging ERC20 and BEP20 pools. Utilizing SmartSwap presents investors with arbitrage opportunities between pools.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4686/smartswap-dapp-defi-bsc-logo_abef342a6b77c719c662a3c85d4a778d.png', 'link': 'https://dappradar.com/dapp/smartswap', 'website': 'https://smartswap.jointer.io', 'chains': ['binance-smart-chain'], 'categories': ['defi'], 'socialLinks': [{'title': 'facebook', 'url': 'https://www.facebook.com/DeFiAuctions', 'type': 'facebook'}, {'title': 'github', 'url': 'https://github.com/jointerinc', 'type': 'github'}, {'title': 'telegram', 'url': 'https://t.me/jointer_io', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/defiauctions', 'type': 'twitter'}], 'tags': []}, {'dappId': 4693, 'name': 'JustLiquidity BNB Farming', 'description': 'JustLiuidity is a Liquidity Protocol which gets integrated with SwapLiquidity and rewards liquidity providers with BNB!', 'fullDescription': '<p>JustLiuidity is a Liquidity Protocol which gets integrated with the SwapLiquidity Exchange and rewards liquidity providers with BNB as well JULb token holders with their unique finance and liquidity engine.</p>\n<p>JULb the JustLiquidity DeFi Token has an elastic supply structure which increases when more liquidity is added, and decreases when liquidity is removed from the Protocol. In this structure, you can just buy JULb on the SwapLiquidity DEX and it will gradually appreciate the price of JUb to our “target price”.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/4693/justliquiditybnbfarming-dapp-defi-bsc-logo_aa5299860cfcb21582011ab23b930ba9.png', 'link': 'https://dappradar.com/dapp/justliquidity-bnb-farming', 'website': 'https://bnbfarm.justliquidity.org/#/pool', 'chains': ['binance-smart-chain'], 'categories': ['exchanges'], 'socialLinks': [{'title': 'github', 'url': 'https://github.com/justliquidity', 'type': 'github'}, {'title': 'medium', 'url': 'https://medium.com/@justliquidity', 'type': 'medium'}, {'title': 'telegram', 'url': 'https://t.me/justliquidity', 'type': 'telegram'}, {'title': 'twitter', 'url': 'https://twitter.com/JustLiquidity', 'type': 'twitter'}], 'tags': []}], 'page': 3, 'pageCount': 506, 'resultCount': 5059, 'resultsPerPage': 10}
#
# --------------------------------

# %% [markdown]
# ### Get top Dapps
#
# This endpoint returns the top dapps by providing the required metric (UAW, volume or transactions) as well as the specified chain, category, range and how many top results are expected.
#
# ```python
# import requests
#
# metric = "YOUR_metric_PARAMETER"
# project = "4tsxo4vuhotaojtl"
# url = "https://api.dappradar.com/" + project + "/dapps/top/" + "UAW"
#
# query = {
#   "chain": "binance-smart-chain",
#   "category": "0",
#   "range": "24h",
#   "top": "10"
# }
#
# headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}
#
# response = requests.get(url, headers=headers, params=query)
#
# data = response.json()
# print(data)
# ```
#
# #### Free trial account does not allow
# {'success': False, 'message': 'Missing Authentication Token'}
# ------------------------------------------------

# %% [markdown]
# ### Get Dapps by research
# ```python
# import requests
#
# project = "4tsxo4vuhotaojtl"
# url = "https://api.dappradar.com/" + project + "/dapps/search"
#
# query = {
#   "chain": "string",
#   "smartContract": "string",
#   "website": "string",
#   "name": "string",
#   "page": "1",
#   "resultsPerPage": "10"
# }
#
# headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}
#
# response = requests.get(url, headers=headers, params=query)
#
# data = response.json()
# print(data)
# ```

# %%
import requests

project = "4tsxo4vuhotaojtl"
url = "https://api.dappradar.com/" + project + "/dapps"

query = {
  "chain": "binance-smart-chain",
  "page": "1",
  "resultsPerPage": "10"
}

headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}

response = requests.get(url, headers=headers, params=query)

data = response.json()
print(data)
# Out:
# {'success': True, 'results': [{'dappId': 13, 'name': 'OpenSea', 'description': 'OpenSea is the first and largest peer-to-peer marketplace.', 'fullDescription': '<p>OpenSea is the first and largest peer-to-peer marketplace for crypto collectibles, which include gaming items, digital art, and other virtual goods backed by a blockchain.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/13/opensea-dapp-marketplaces-ethereum-logo_a3421ac6e32d529db3c8293f4cfa9bcd.png', 'link': 'https://dappradar.com/dapp/opensea', 'website': 'https://opensea.io', 'chains': ['arbitrum', 'avalanche', 'base', 'binance-smart-chain', 'ethereum', 'klaytn', 'optimism', 'polygon', 'solana'], 'categories': ['marketplaces'], 'socialLinks': [{'title': 'discord', 'url': 'https://discord.gg/zAHt7Tb', 'type': 'discord'}, {'title': 'facebook', 'url': 'https://facebook.com/projectopensea', 'type': 'facebook'}, {'title': 'medium', 'url': 'https://medium.com/@opensea', 'type': 'medium'}, {'titl
# ...

# %%
import requests

dapp_id = "YOUR_dappId_PARAMETER" #Need to provide adappId in order to run the following code.
project = "4tsxo4vuhotaojtl"
url = "https://api.dappradar.com/" + project + "/dapps/" + "13"

query = {
  "chain": "binance-smart-chain",
  "range": "24h"
}

headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}

response = requests.get(url, headers=headers, params=query)

data = response.json()
print(data)
# Out:
# {'success': True, 'range': '24h', 'chain': 'binance-smart-chain', 'results': {'dappId': 13, 'name': 'OpenSea', 'description': 'OpenSea is the first and largest peer-to-peer marketplace.', 'fullDescription': '<p>OpenSea is the first and largest peer-to-peer marketplace for crypto collectibles, which include gaming items, digital art, and other virtual goods backed by a blockchain.</p>', 'logo': 'https://dashboard-assets.dappradar.com/geRRcWz9IdTwSrm1/document/13/opensea-dapp-marketplaces-ethereum-logo-166x166_f8aad6af2930b1edbeaee6457a505d1b.png', 'link': 'https://dappradar.com/dapp/opensea', 'website': 'https://opensea.io', 'tokens': [], 'categories': ['marketplaces'], 'socialLinks': [{'title': 'twitter', 'url': 'https://twitter.com/projectopensea', 'type': 'twitter'}, {'title': 'medium', 'url': 'https://medium.com/@opensea', 'type': 'medium'}, {'title': 'discord', 'url': 'https://discord.gg/zAHt7Tb', 'type': 'discord'}, {'title': 'reddit', 'url': 'https://reddit.com/r/opensea', 'typ
# ...

# %%
import requests

project = "4tsxo4vuhotaojtl"
url = "https://api.dappradar.com/" + project + "/dapps"

query = {
  "chain": "binance-smart-chain",
  "page": "3",
  "resultsPerPage": "10"
}

headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}

response = requests.get(url, headers=headers, params=query)

data = response.json()
print(data)
# Out:
# {'success': True, 'results': [{'dappId': 4601, 'name': 'Beefy Finance', 'description': 'The Multichain Yield Optimizer that autocompounds your crypto on BSC, Polygon, Fantom, HECO and Avalanche', 'fullDescription': "<p>Beefy Finance is a Decentralized, Multi-Chain Yield Optimizer platform that allows its users to earn compound interest on their crypto holdings.</p>\n<p>Through a set of investment strategies secured and enforced by smart contracts, Beefy Finance automatically maximizes the user rewards from various liquidity pools (LPs),\u200c \u200cautomated market making (AMM) projects,\u200c \u200cand\u200c \u200cother yield\u200c farming \u200copportunities in the DeFi ecosystem.</p>\n<p>The main product offered by Beefy Finance are the 'Vaults' in which you stake your crypto tokens. The investment strategy tied to the specific vault will automatically increase your deposited token amount by compounding arbitrary yield farm reward tokens back into your initially deposited asset. D
# ...

# %%
import requests

metric = "YOUR_metric_PARAMETER"
project = "4tsxo4vuhotaojtl"
url = "https://api.dappradar.com/" + project + "/dapps/top/" + "UAW"

query = {
  "chain": "binance-smart-chain",
  "category": "0",
  "range": "24h",
  "top": "10"
}

headers = {"X-BLOBR-KEY": "XboyJNloHLbWAAsEntXoLdL0fBK42R0N"}

response = requests.get(url, headers=headers, params=query)

data = response.json()
print(data)
# Out:
# {'success': False, 'message': 'Missing Authentication Token'}
